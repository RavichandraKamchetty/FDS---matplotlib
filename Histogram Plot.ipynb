# %% [markdown]
# # Histogram Plot

# %%
import matplotlib.pyplot as plt
import numpy as np
import random

# %%
x = np.random.randint(10, 60, 50)

# %%
no = [46, 56, 57, 35, 30, 33, 48, 10, 58, 34, 13, 55, 18, 17, 49, 51, 17, 52, 42, 28, 27, 40, 59, 26, 
 38, 43, 19, 30, 26, 30, 52, 25, 12, 15, 36, 36, 54, 38, 49, 46, 22, 26, 
 56, 20, 24, 55, 33, 17, 40, 12]

l = [10, 20, 30, 40, 50, 60]
plt.hist(no, bins = l, edgecolor = 'r', histtype = "bar", orientation = "vertical", rwidth = 0.8)

plt.title("RC", fontsize = 15)
plt.xlabel("Python", fontsize = 15)
plt.ylabel("No.", fontsize = 15)

plt.show()

# %%
no = [46, 56, 57, 35, 30, 33, 48, 10, 58, 34, 13, 55, 18, 17, 49, 51, 17, 52, 42, 28, 27, 40, 59, 26, 
 38, 43, 19, 30, 26, 30, 52, 25, 12, 15, 36, 36, 54, 38, 49, 46, 22, 26, 
 56, 20, 24, 55, 33, 17, 40, 12]

l = [10, 20, 30, 40, 50, 60]
plt.hist(no, "auto", (0, 100), edgecolor = 'r')

plt.title("RC", fontsize = 15)
plt.xlabel("Python", fontsize = 15)
plt.ylabel("No.", fontsize = 15)

plt.show()

# %%
no = [46, 56, 57, 35, 30, 33, 48, 10, 58, 34, 13, 55, 18, 17, 49, 51, 17, 52, 42, 28, 27, 40, 59, 26, 
 38, 43, 19, 30, 26, 30, 52, 25, 12, 15, 36, 36, 54, 38, 49, 46, 22, 26, 
 56, 20, 24, 55, 33, 17, 40, 12]

l = [10, 20, 30, 40, 50, 60]
plt.hist(no, edgecolor = 'r', cumulative = -1)

plt.title("RC", fontsize = 15)
plt.xlabel("Python", fontsize = 15)
plt.ylabel("No.", fontsize = 15)

plt.show()

# %%
no = [46, 56, 57, 35, 30, 33, 48, 10, 58, 34, 13, 55, 18, 17, 49, 51, 17, 52, 42, 28, 27, 40, 59, 26, 
 38, 43, 19, 30, 26, 30, 52, 25, 12, 15, 36, 36, 54, 38, 49, 46, 22, 26, 
 56, 20, 24, 55, 33, 17, 40, 12]

plt.hist(no, edgecolor = 'r', align = "mid")

plt.title("RC", fontsize = 15)
plt.xlabel("Python", fontsize = 15)
plt.ylabel("No.", fontsize = 15)

plt.show()

# %%
no = [46, 56, 57, 35, 30, 33, 48, 10, 58, 34, 13, 55, 18, 17, 49, 51, 17, 52, 42, 28, 27, 40, 59, 26, 
 38, 43, 19, 30, 26, 30, 52, 25, 12, 15, 36, 36, 54, 38, 49, 46, 22, 26, 
 56, 20, 24, 55, 33, 17, 40, 12]

l = [10, 20, 30, 40, 50, 60]
plt.hist(no, bins = l, edgecolor = 'r', log = True)

plt.title("RC", fontsize = 15)
plt.xlabel("Python", fontsize = 15)
plt.ylabel("No.", fontsize = 15)

plt.show()

# %%
no = [46, 56, 57, 35, 30, 33, 48, 10, 58, 34, 13, 55, 18, 17, 49, 51, 17, 52, 42, 28, 27, 40, 59, 26, 
 38, 43, 19, 30, 26, 30, 52, 25, 12, 15, 36, 36, 54, 38, 49, 46, 22, 26, 
 56, 20, 24, 55, 33, 17, 40, 12]

l = [10, 20, 30, 40, 50, 60]
plt.hist(no, bins = l, edgecolor = 'r', label = "python")

plt.title("RC", fontsize = 15)
plt.xlabel("Python", fontsize = 15)
plt.ylabel("No.", fontsize = 15)

plt.axvline(45, color = 'g', label = "line")
plt.grid()
plt.legend()
plt.show()
